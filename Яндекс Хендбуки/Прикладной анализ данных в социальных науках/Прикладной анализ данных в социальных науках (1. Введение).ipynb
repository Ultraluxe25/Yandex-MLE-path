# %% [markdown]
# ![image.png](attachment:2b48e091-89ba-4c4d-84d7-c3091edb90b9.png)

# %% [markdown]
# ### Хендбук — это цифровой учебник, который содержит теорию и практические задания с автопроверкой.

# %% [markdown]
# ### Сегодня возросла цена ошибки: сейчас гораздо дешевле проверить гипотезу заранее, чем сначала реализовать непроверенное решение, а потом разбираться с последствиями.

# %% [markdown]
# ![image.png](attachment:a6ca9184-db3c-4f7f-a974-1326f8b9e61a.png)

# %% [markdown]
# ![image.png](attachment:914e3d65-4302-4034-8c3a-1730ed863771.png)

# %% [markdown]
# ![image.png](attachment:1068292e-d1ef-4f49-b0bd-9760052866c7.png)

# %% [markdown]
# ![image.png](attachment:cc393e79-0793-4c17-a0f8-645788de7f6c.png)

# %% [markdown]
# ### Выведем день месяца
# ![image.png](attachment:d0be3fa0-e64f-4713-9790-dcd6be256446.png)

# %% [markdown]
# ![image.png](attachment:7def541e-e7e0-48c9-a74a-768c74f49fde.png)

# %% [markdown]
# ### Создаем папку и переходим в нее
# ![image.png](attachment:01bc43b4-c377-4c9b-bd7b-040c95aa9cfb.png)

# %% [markdown]
# ![image.png](attachment:c14fdbe3-60a0-4b17-b949-cea61e27d1d3.png)

# %% [markdown]
# ![image.png](attachment:f699d7c8-51ee-4b4b-b0a3-e4c08ad1fef9.png)

# %% [markdown]
# ![image.png](attachment:15ee9717-ed46-48e4-b959-fe85f4c3bd6c.png)

# %% [markdown]
# ![image.png](attachment:2f91ef04-eec3-4e09-b7e0-639ab58b326a.png)

# %% [markdown]
# ### Каждый раз при установки нового приложения, чтобы оно было видно в командной строке нужно перезагрузить командную строку

# %% [markdown]
# ![image.png](attachment:6d80bdec-4d09-46ef-a3dd-dc9489dbe2b1.png)

# %% [markdown]
# ![image.png](attachment:1f395225-aa8e-47b1-988e-b4b9f4dd5464.png)

# %% [markdown]
# ![image.png](attachment:c70a255e-1d63-473d-90c6-a171deafe0af.png)

# %% [markdown]
# ![image.png](attachment:9e6a7e63-0f3d-43db-b88a-a0fca75a835c.png)
# ![image.png](attachment:88e47fb5-a4cd-4c5f-87e8-84be64401e51.png)

# %% [markdown]
# ```Bash
# wget -O 01.webp https://img-9gag-fun.9cache.com/photo/aVbxpod_460swp.webp
# magick 01.webp 01.png
# tesseract 01.png 01
# Get-Content 01.txt | Measure-Object -Word
# ```

# %% [markdown]
# ### pip — это специальная программа для установки дополнений (их ещё называют библиотеками) для Python.

# %% [markdown]
# ![image.png](attachment:0d4b4f07-3f5f-4b54-89b1-7e07cea9e253.png)

# %% [markdown]
# ### Вы можете заметить, что он выглядит как Colab. Это не случайно. Дело в том, что Colab — это просто ещё одна версия Jupyter Notebooks.

# %% [markdown]
# ![image.png](attachment:fea4192f-2929-49fe-abc8-18a30413d516.png)

# %% [markdown]
# ![image.png](attachment:c9ab480d-fe83-45c7-a171-422109cde4ff.png)

# %% [markdown]
# ![image.png](attachment:e5ca7287-51b7-4b85-907c-b467bacb9c24.png)

# %% [markdown]
# ![image.png](attachment:ef087af7-bb93-4e71-a64d-481cc1f4c296.png)

# %% [markdown]
# ![image.png](attachment:9fdcc019-f113-4bc3-b466-0007155a8b7d.png)

# %% [markdown]
# ![image.png](attachment:4e111a0a-c1a1-4e43-9a73-33ce55729b7d.png)

# %% [markdown]
# ![image.png](attachment:61651b6c-8837-4b7e-a6d4-a92fd8a386bd.png)

# %% [markdown]
# ![image.png](attachment:92040e54-f2a9-462e-ad25-19c454aee9cc.png)

# %% [markdown]
# ![image.png](attachment:ab638ea1-a98c-4257-958d-63f927256b90.png)

# %% [markdown]
# ![image.png](attachment:aee45f91-7a1c-45cc-98e7-25d5d57d413a.png)
